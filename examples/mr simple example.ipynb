# %% [markdown]
# ## Locate Features
# To begin, import the microrheology package.

# %%
import mr

# %% [markdown]
# ### Open a video
# Load a video file as a frames. This object is an iterator that returns a frame each time as its called. The frame is a ``numpy.ndarray`` of brightness values.

# %%
frames = mr.Video('../mr/mr/tests/water/bulk-water.mov')

# %%
frames
# Out:
# <Frames>
# Source File: ../mr/mr/tests/water/bulk-water.mov
# Frame Dimensions: 640 x 424
# Cursor at Frame 0 of 480

# %% [markdown]
# The ``Video`` constructor assumes brightfield video, inverting black and white. (See image below.) To process video of fluorescent particles, include the keyword argument ``invert=False``.

# %%
mr.play(frames) # spawn a window playing the video

# %% [markdown]
# ### Find features in one frame.
# Take a look at, say, Frame 5.

# %%
imshow(frames[5], cmap=cm.gray)

# %% [markdown]
# Locate bright features with a diameter of about 11 px. The size must be an odd integer, and it usually best to err on the large side.

# %%
f = mr.locate(frames[5], 11)
# Out:
# mr.core.feature.locate:  706 local maxima, 706 of qualifying mass

# %%
f.head() # shows the first few rows of data
# Out:
#             x         y  mass      size       ecc     signal        ep
# 0   69.247590  6.001033  2904  2.576515  0.068097  21.477955  0.441745
# 1  205.887584  6.423932  4003  2.935351  0.170811  24.477955  0.298631
# 2  306.325329  7.351058  1749  3.098811  0.171040   9.477955  0.692030
# 3  336.212858  6.298217  1851  1.929329  0.099857  24.477955  0.691261
# 4   36.225710  8.205786  3664  2.843584  0.144773  22.477955  0.346530

# %%
mr.annotate(f, frames[5])

# %% [markdown]
# **Many of these are spurious**; they are fleeting peaks in brightness that aren't actually particles. To filter these, consider the total brightness ("mass") in the neighborhood of the peak, and filter all features below some threshold.

# %%
f['mass'].hist()
xlabel('mass'); ylabel('count')

# %%
f = mr.locate(frames[5], 11, minmass=2000)
# Out:
# mr.core.feature.locate:  706 local maxima, 429 of qualifying mass

# %%
mr.annotate(frames[5], f)

# %% [markdown]
# ### Check for subpixel accuracy.
# As Eric Weeks points out in the tutorial for his tutorial, a quick way to check for subpixel accuracy is to check that the decimal part of the x and/or y positions are evenly distributed. ``mr`` provides a convenience function for this:

# %%
mr.subpx_bias(f)

# %% [markdown]
# If we use a mask size that is too small, the histogram often shows a dip in the middle.

# %%
mr.subpx_bias(mr.locate(frames[5], 7))
# Out:
# mr.core.feature.locate:  895 local maxima, 895 of qualifying mass

# %% [markdown]
# ### Find features in all frames.
# You can get:
#
# * all frames, ``frames[:]``
# * a range of frames, like ``frames[100:200]``
# * all frames after a starting frames, like ``frames[100:]``
# * a list of specific frames, like ``frames[[100, 107, 113]]``
#
# We'll locate features in the first 300 frames from this video. A log reports the progress...

# %%
f = mr.batch(frames[:300], 11, minmass=2000)
# Out:
# mr.core.feature.locate:  693 local maxima, 493 of qualifying mass
# mr.core.feature.batch:  Frame 0: 493 features
# mr.core.feature.locate:  695 local maxima, 465 of qualifying mass
# mr.core.feature.batch:  Frame 1: 465 features
# mr.core.feature.locate:  702 local maxima, 467 of qualifying mass
# mr.core.feature.batch:  Frame 2: 467 features
# mr.core.feature.locate:  706 local maxima, 472 of qualifying mass
# mr.core.feature.batch:  Frame 3: 472 features
# mr.core.feature.locate:  703 local maxima, 447 of qualifying mass
# mr.core.feature.batch:  Frame 4: 447 features
# mr.core.feature.locate:  706 local maxima, 429 of qualifying mass
# mr.core.feature.batch:  Frame 5: 429 features
# mr.core.feature.locate:  703 local maxima, 447 of qualifying mass
# mr.core.feature.batch:  Frame 6: 447 features
# mr.core.feature.locate:  698 local maxima, 452 of qualifying mass
# mr.core.feature.batch:  Frame 7: 452 features
# mr.core.feature.locate:  709 local maxima, 447 of qualifying mass
# mr.core.feature.batch:  Frame 8: 447 features
# mr.core.feature.locate:  709 local maxima, 455 of qualifying mass
# mr.core.feature.batch:  Frame 9: 455 features
# mr.core.feature.locate:  704 local maxima, 464 of qualifying mass
# mr.core.feature.batch:  Frame 10: 464 features
# mr.core.feature.locate:  702 local maxima, 468 of qualifying mass
# mr.core.feature.batch:  Frame 11: 468 features
# mr.core.feature.locate:  709 local maxima, 456 of qualifying mass
# mr.core.feature.batch:  Frame 12: 456 features
# mr.core.feature.locate:  702 local maxima, 503 of qualifying mass
# mr.core.feature.batch:  Frame 13: 503 features
# mr.core.feature.locate:  703 local maxima, 509 of qualifying mass
# mr.core.feature.batch:  Frame 14: 509 features
# mr.core.feature.locate:  695 local maxima, 511 of qualifying mass
# mr.core.feature.batch:  Frame 15: 511 features
# mr.core.feature.locate:  704 local maxima, 492 of qualifying mass
# mr.core.feature.batch:  Frame 16: 492 features
# mr.core.feature.locate:  712 local maxima, 489 of qualifying mass
# mr.core.feature.batch:  Frame 17: 489 features
# mr.core.feature.locate:  711 local maxima, 502 of qualifying mass
# mr.core.feature.batch:  Frame 18: 502 features
# mr.core.feature.locate:  714 local maxima, 495 of qualifying mass
# mr.core.feature.batch:  Frame 19: 495 features
# mr.core.feature.locate:  709 local maxima, 503 of qualifying mass
# mr.core.feature.batch:  Frame 20: 503 features
# mr.core.feature.locate:  707 local maxima, 495 of qualifying mass
# mr.core.feature.batch:  Frame 21: 495 features
# mr.core.feature.locate:  702 local maxima, 488 of qualifying mass
# mr.core.feature.batch:  Frame 22: 488 features
# mr.core.feature.locate:  703 local maxima, 474 of qualifying mass
# mr.core.feature.batch:  Frame 23: 474 features
# mr.core.feature.locate:  701 local maxima, 494 of qualifying mass
# mr.core.feature.batch:  Frame 24: 494 features
# mr.core.feature.locate:  705 local maxima, 469 of qualifying mass
# mr.core.feature.batch:  Frame 25: 469 features
# mr.core.feature.locate:  716 local maxima, 480 of qualifying mass
# mr.core.feature.batch:  Frame 26: 480 features
# mr.core.feature.locate:  725 local maxima, 485 of qualifying mass
# mr.core.feature.batch:  Frame 27: 485 features
# mr.core.feature.locate:  714 local maxima, 494 of qualifying mass
# mr.core.feature.batch:  Frame 28: 494 features
# mr.core.feature.locate:  716 local maxima, 503 of qualifying mass
# mr.core.feature.batch:  Frame 29: 503 features
# mr.core.feature.locate:  709 local maxima, 507 of qualifying mass
# mr.core.feature.batch:  Frame 30: 507 features
# mr.core.feature.locate:  707 local maxima, 500 of qualifying mass
# mr.core.feature.batch:  Frame 31: 500 features
# mr.core.feature.locate:  721 local maxima, 508 of qualifying mass
# mr.core.feature.batch:  Frame 32: 508 features
# mr.core.feature.locate:  720 local maxima, 492 of qualifying mass
# mr.core.feature.batch:  Frame 33: 492 features
# mr.core.feature.locate:  717 local maxima, 490 of qualifying mass
# mr.core.feature.batch:  Frame 34: 490 features
# mr.core.feature.locate:  709 local maxima, 477 of qualifying mass
# mr.core.feature.batch:  Frame 35: 477 features
# mr.core.feature.locate:  715 local maxima, 505 of qualifying mass
# mr.core.feature.batch:  Frame 36: 505 features
# mr.core.feature.locate:  716 local maxima, 472 of qualifying mass
# mr.core.feature.batch:  Frame 37: 472 features
# mr.core.feature.locate:  705 local maxima, 475 of qualifying mass
# mr.core.feature.batch:  Frame 38: 475 features
# mr.core.feature.locate:  716 local maxima, 479 of qualifying mass
# mr.core.feature.batch:  Frame 39: 479 features
# mr.core.feature.locate:  715 local maxima, 466 of qualifying mass
# mr.core.feature.batch:  Frame 40: 466 features
# mr.core.feature.locate:  706 local maxima, 483 of qualifying mass
# mr.core.feature.batch:  Frame 41: 483 features
# mr.core.feature.locate:  698 local maxima, 459 of qualifying mass
# mr.core.feature.batch:  Frame 42: 459 features
# mr.core.feature.locate:  696 local maxima, 483 of qualifying mass
# mr.core.feature.batch:  Frame 43: 483 features
# mr.core.feature.locate:  708 local maxima, 493 of qualifying mass
# mr.core.feature.batch:  Frame 44: 493 features
# mr.core.feature.locate:  705 local maxima, 479 of qualifying mass
# mr.core.feature.batch:  Frame 45: 479 features
# mr.core.feature.locate:  706 local maxima, 467 of qualifying mass
# mr.core.feature.batch:  Frame 46: 467 features
# mr.core.feature.locate:  697 local maxima, 458 of qualifying mass
# mr.core.feature.batch:  Frame 47: 458 features
# mr.core.feature.locate:  717 local maxima, 475 of qualifying mass
# mr.core.feature.batch:  Frame 48: 475 features
# mr.core.feature.locate:  697 local maxima, 477 of qualifying mass
# mr.core.feature.batch:  Frame 49: 477 features
# mr.core.feature.locate:  704 local maxima, 478 of qualifying mass
# mr.core.feature.batch:  Frame 50: 478 features
# mr.core.feature.locate:  699 local maxima, 471 of qualifying mass
# mr.core.feature.batch:  Frame 51: 471 features
# mr.core.feature.locate:  707 local maxima, 477 of qualifying mass
# mr.core.feature.batch:  Frame 52: 477 features
# mr.core.feature.locate:  709 local maxima, 474 of qualifying mass
# mr.core.feature.batch:  Frame 53: 474 features
# mr.core.feature.locate:  705 local maxima, 475 of qualifying mass
# mr.core.feature.batch:  Frame 54: 475 features
# mr.core.feature.locate:  704 local maxima, 467 of qualifying mass
# mr.core.feature.batch:  Frame 55: 467 features
# mr.core.feature.locate:  693 local maxima, 472 of qualifying mass
# mr.core.feature.batch:  Frame 56: 472 features
# mr.core.feature.locate:  693 local maxima, 476 of qualifying mass
# mr.core.feature.batch:  Frame 57: 476 features
# mr.core.feature.locate:  708 local maxima, 501 of qualifying mass
# mr.core.feature.batch:  Frame 58: 501 features
# mr.core.feature.locate:  703 local maxima, 480 of qualifying mass
# mr.core.feature.batch:  Frame 59: 480 features
# mr.core.feature.locate:  696 local maxima, 488 of qualifying mass
# mr.core.feature.batch:  Frame 60: 488 features
# mr.core.feature.locate:  705 local maxima, 477 of qualifying mass
# mr.core.feature.batch:  Frame 61: 477 features
# mr.core.feature.locate:  707 local maxima, 473 of qualifying mass
# mr.core.feature.batch:  Frame 62: 473 features
# mr.core.feature.locate:  695 local maxima, 478 of qualifying mass
# mr.core.feature.batch:  Frame 63: 478 features
# mr.core.feature.locate:  701 local maxima, 496 of qualifying mass
# mr.core.feature.batch:  Frame 64: 496 features
# mr.core.feature.locate:  686 local maxima, 482 of qualifying mass
# mr.core.feature.batch:  Frame 65: 482 features
# mr.core.feature.locate:  689 local maxima, 517 of qualifying mass
# mr.core.feature.batch:  Frame 66: 517 features
# mr.core.feature.locate:  691 local maxima, 495 of qualifying mass
# mr.core.feature.batch:  Frame 67: 495 features
# mr.core.feature.locate:  698 local maxima, 505 of qualifying mass
# mr.core.feature.batch:  Frame 68: 505 features
# mr.core.feature.locate:  690 local maxima, 487 of qualifying mass
# mr.core.feature.batch:  Frame 69: 487 features
# mr.core.feature.locate:  689 local maxima, 480 of qualifying mass
# mr.core.feature.batch:  Frame 70: 480 features
# mr.core.feature.locate:  694 local maxima, 470 of qualifying mass
# mr.core.feature.batch:  Frame 71: 470 features
# mr.core.feature.locate:  703 local maxima, 484 of qualifying mass
# mr.core.feature.batch:  Frame 72: 484 features
# mr.core.feature.locate:  693 local maxima, 493 of qualifying mass
# mr.core.feature.batch:  Frame 73: 493 features
# mr.core.feature.locate:  687 local maxima, 487 of qualifying mass
# mr.core.feature.batch:  Frame 74: 487 features
# mr.core.feature.locate:  693 local maxima, 498 of qualifying mass
# mr.core.feature.batch:  Frame 75: 498 features
# mr.core.feature.locate:  691 local maxima, 486 of qualifying mass
# mr.core.feature.batch:  Frame 76: 486 features
# mr.core.feature.locate:  686 local maxima, 499 of qualifying mass
# mr.core.feature.batch:  Frame 77: 499 features
# mr.core.feature.locate:  697 local maxima, 499 of qualifying mass
# mr.core.feature.batch:  Frame 78: 499 features
# mr.core.feature.locate:  692 local maxima, 506 of qualifying mass
# mr.core.feature.batch:  Frame 79: 506 features
# mr.core.feature.locate:  692 local maxima, 496 of qualifying mass
# mr.core.feature.batch:  Frame 80: 496 features
# mr.core.feature.locate:  694 local maxima, 491 of qualifying mass
# mr.core.feature.batch:  Frame 81: 491 features
# mr.core.feature.locate:  688 local maxima, 485 of qualifying mass
# mr.core.feature.batch:  Frame 82: 485 features
# mr.core.feature.locate:  686 local maxima, 473 of qualifying mass
# mr.core.feature.batch:  Frame 83: 473 features
# mr.core.feature.locate:  689 local maxima, 495 of qualifying mass
# mr.core.feature.batch:  Frame 84: 495 features
# mr.core.feature.locate:  705 local maxima, 488 of qualifying mass
# mr.core.feature.batch:  Frame 85: 488 features
# mr.core.feature.locate:  692 local maxima, 469 of qualifying mass
# mr.core.feature.batch:  Frame 86: 469 features
# mr.core.feature.locate:  699 local maxima, 488 of qualifying mass
# mr.core.feature.batch:  Frame 87: 488 features
# mr.core.feature.locate:  699 local maxima, 464 of qualifying mass
# mr.core.feature.batch:  Frame 88: 464 features
# mr.core.feature.locate:  704 local maxima, 483 of qualifying mass
# mr.core.feature.batch:  Frame 89: 483 features
# mr.core.feature.locate:  691 local maxima, 453 of qualifying mass
# mr.core.feature.batch:  Frame 90: 453 features
# mr.core.feature.locate:  695 local maxima, 485 of qualifying mass
# mr.core.feature.batch:  Frame 91: 485 features
# mr.core.feature.locate:  702 local maxima, 466 of qualifying mass
# mr.core.feature.batch:  Frame 92: 466 features
# mr.core.feature.locate:  701 local maxima, 447 of qualifying mass
# mr.core.feature.batch:  Frame 93: 447 features
# mr.core.feature.locate:  713 local maxima, 438 of qualifying mass
# mr.core.feature.batch:  Frame 94: 438 features
# mr.core.feature.locate:  710 local maxima, 440 of qualifying mass
# mr.core.feature.batch:  Frame 95: 440 features
# mr.core.feature.locate:  722 local maxima, 482 of qualifying mass
# mr.core.feature.batch:  Frame 96: 482 features
# mr.core.feature.locate:  712 local maxima, 450 of qualifying mass
# mr.core.feature.batch:  Frame 97: 450 features
# mr.core.feature.locate:  720 local maxima, 501 of qualifying mass
# mr.core.feature.batch:  Frame 98: 501 features
# mr.core.feature.locate:  718 local maxima, 497 of qualifying mass
# mr.core.feature.batch:  Frame 99: 497 features
# mr.core.feature.locate:  717 local maxima, 479 of qualifying mass
# mr.core.feature.batch:  Frame 100: 479 features
# mr.core.feature.locate:  719 local maxima, 484 of qualifying mass
# mr.core.feature.batch:  Frame 101: 484 features
# mr.core.feature.locate:  718 local maxima, 467 of qualifying mass
# mr.core.feature.batch:  Frame 102: 467 features
# mr.core.feature.locate:  723 local maxima, 488 of qualifying mass
# mr.core.feature.batch:  Frame 103: 488 features
# mr.core.feature.locate:  709 local maxima, 473 of qualifying mass
# mr.core.feature.batch:  Frame 104: 473 features
# mr.core.feature.locate:  717 local maxima, 449 of qualifying mass
# mr.core.feature.batch:  Frame 105: 449 features
# mr.core.feature.locate:  716 local maxima, 470 of qualifying mass
# mr.core.feature.batch:  Frame 106: 470 features
# mr.core.feature.locate:  706 local maxima, 460 of qualifying mass
# mr.core.feature.batch:  Frame 107: 460 features
# mr.core.feature.locate:  713 local maxima, 487 of qualifying mass
# mr.core.feature.batch:  Frame 108: 487 features
# mr.core.feature.locate:  704 local maxima, 487 of qualifying mass
# mr.core.feature.batch:  Frame 109: 487 features
# mr.core.feature.locate:  710 local maxima, 513 of qualifying mass
# mr.core.feature.batch:  Frame 110: 513 features
# mr.core.feature.locate:  708 local maxima, 490 of qualifying mass
# mr.core.feature.batch:  Frame 111: 490 features
# mr.core.feature.locate:  699 local maxima, 485 of qualifying mass
# mr.core.feature.batch:  Frame 112: 485 features
# mr.core.feature.locate:  704 local maxima, 487 of qualifying mass
# mr.core.feature.batch:  Frame 113: 487 features
# mr.core.feature.locate:  694 local maxima, 499 of qualifying mass
# mr.core.feature.batch:  Frame 114: 499 features
# mr.core.feature.locate:  694 local maxima, 513 of qualifying mass
# mr.core.feature.batch:  Frame 115: 513 features
# mr.core.feature.locate:  701 local maxima, 500 of qualifying mass
# mr.core.feature.batch:  Frame 116: 500 features
# mr.core.feature.locate:  691 local maxima, 495 of qualifying mass
# mr.core.feature.batch:  Frame 117: 495 features
# mr.core.feature.locate:  700 local maxima, 485 of qualifying mass
# mr.core.feature.batch:  Frame 118: 485 features
# mr.core.feature.locate:  695 local maxima, 487 of qualifying mass
# mr.core.feature.batch:  Frame 119: 487 features
# mr.core.feature.locate:  707 local maxima, 476 of qualifying mass
# mr.core.feature.batch:  Frame 120: 476 features
# mr.core.feature.locate:  697 local maxima, 499 of qualifying mass
# mr.core.feature.batch:  Frame 121: 499 features
# mr.core.feature.locate:  695 local maxima, 503 of qualifying mass
# mr.core.feature.batch:  Frame 122: 503 features
# mr.core.feature.locate:  699 local maxima, 504 of qualifying mass
# mr.core.feature.batch:  Frame 123: 504 features
# mr.core.feature.locate:  704 local maxima, 503 of qualifying mass
# mr.core.feature.batch:  Frame 124: 503 features
# mr.core.feature.locate:  703 local maxima, 480 of qualifying mass
# mr.core.feature.batch:  Frame 125: 480 features
# mr.core.feature.locate:  707 local maxima, 483 of qualifying mass
# mr.core.feature.batch:  Frame 126: 483 features
# mr.core.feature.locate:  700 local maxima, 490 of qualifying mass
# mr.core.feature.batch:  Frame 127: 490 features
# mr.core.feature.locate:  709 local maxima, 493 of qualifying mass
# mr.core.feature.batch:  Frame 128: 493 features
# mr.core.feature.locate:  709 local maxima, 497 of qualifying mass
# mr.core.feature.batch:  Frame 129: 497 features
# mr.core.feature.locate:  709 local maxima, 477 of qualifying mass
# mr.core.feature.batch:  Frame 130: 477 features
# mr.core.feature.locate:  713 local maxima, 494 of qualifying mass
# mr.core.feature.batch:  Frame 131: 494 features
# mr.core.feature.locate:  711 local maxima, 499 of qualifying mass
# mr.core.feature.batch:  Frame 132: 499 features
# mr.core.feature.locate:  717 local maxima, 502 of qualifying mass
# mr.core.feature.batch:  Frame 133: 502 features
# mr.core.feature.locate:  707 local maxima, 504 of qualifying mass
# mr.core.feature.batch:  Frame 134: 504 features
# mr.core.feature.locate:  701 local maxima, 494 of qualifying mass
# mr.core.feature.batch:  Frame 135: 494 features
# mr.core.feature.locate:  703 local maxima, 493 of qualifying mass
# mr.core.feature.batch:  Frame 136: 493 features
# mr.core.feature.locate:  689 local maxima, 488 of qualifying mass
# mr.core.feature.batch:  Frame 137: 488 features
# mr.core.feature.locate:  703 local maxima, 486 of qualifying mass
# mr.core.feature.batch:  Frame 138: 486 features
# mr.core.feature.locate:  699 local maxima, 497 of qualifying mass
# mr.core.feature.batch:  Frame 139: 497 features
# mr.core.feature.locate:  700 local maxima, 506 of qualifying mass
# mr.core.feature.batch:  Frame 140: 506 features
# mr.core.feature.locate:  688 local maxima, 493 of qualifying mass
# mr.core.feature.batch:  Frame 141: 493 features
# mr.core.feature.locate:  692 local maxima, 519 of qualifying mass
# mr.core.feature.batch:  Frame 142: 519 features
# mr.core.feature.locate:  700 local maxima, 508 of qualifying mass
# mr.core.feature.batch:  Frame 143: 508 features
# mr.core.feature.locate:  685 local maxima, 510 of qualifying mass
# mr.core.feature.batch:  Frame 144: 510 features
# mr.core.feature.locate:  699 local maxima, 494 of qualifying mass
# mr.core.feature.batch:  Frame 145: 494 features
# mr.core.feature.locate:  699 local maxima, 492 of qualifying mass
# mr.core.feature.batch:  Frame 146: 492 features
# mr.core.feature.locate:  689 local maxima, 490 of qualifying mass
# mr.core.feature.batch:  Frame 147: 490 features
# mr.core.feature.locate:  684 local maxima, 486 of qualifying mass
# mr.core.feature.batch:  Frame 148: 486 features
# mr.core.feature.locate:  683 local maxima, 491 of qualifying mass
# mr.core.feature.batch:  Frame 149: 491 features
# mr.core.feature.locate:  689 local maxima, 500 of qualifying mass
# mr.core.feature.batch:  Frame 150: 500 features
# mr.core.feature.locate:  687 local maxima, 478 of qualifying mass
# mr.core.feature.batch:  Frame 151: 478 features
# mr.core.feature.locate:  685 local maxima, 507 of qualifying mass
# mr.core.feature.batch:  Frame 152: 507 features
# mr.core.feature.locate:  692 local maxima, 503 of qualifying mass
# mr.core.feature.batch:  Frame 153: 503 features
# mr.core.feature.locate:  685 local maxima, 475 of qualifying mass
# mr.core.feature.batch:  Frame 154: 475 features
# mr.core.feature.locate:  685 local maxima, 446 of qualifying mass
# mr.core.feature.batch:  Frame 155: 446 features
# mr.core.feature.locate:  685 local maxima, 482 of qualifying mass
# mr.core.feature.batch:  Frame 156: 482 features
# mr.core.feature.locate:  690 local maxima, 488 of qualifying mass
# mr.core.feature.batch:  Frame 157: 488 features
# mr.core.feature.locate:  680 local maxima, 478 of qualifying mass
# mr.core.feature.batch:  Frame 158: 478 features
# mr.core.feature.locate:  683 local maxima, 457 of qualifying mass
# mr.core.feature.batch:  Frame 159: 457 features
# mr.core.feature.locate:  685 local maxima, 449 of qualifying mass
# mr.core.feature.batch:  Frame 160: 449 features
# mr.core.feature.locate:  674 local maxima, 462 of qualifying mass
# mr.core.feature.batch:  Frame 161: 462 features
# mr.core.feature.locate:  696 local maxima, 460 of qualifying mass
# mr.core.feature.batch:  Frame 162: 460 features
# mr.core.feature.locate:  690 local maxima, 467 of qualifying mass
# mr.core.feature.batch:  Frame 163: 467 features
# mr.core.feature.locate:  691 local maxima, 471 of qualifying mass
# mr.core.feature.batch:  Frame 164: 471 features
# mr.core.feature.locate:  689 local maxima, 467 of qualifying mass
# mr.core.feature.batch:  Frame 165: 467 features
# mr.core.feature.locate:  691 local maxima, 466 of qualifying mass
# mr.core.feature.batch:  Frame 166: 466 features
# mr.core.feature.locate:  695 local maxima, 480 of qualifying mass
# mr.core.feature.batch:  Frame 167: 480 features
# mr.core.feature.locate:  699 local maxima, 507 of qualifying mass
# mr.core.feature.batch:  Frame 168: 507 features
# mr.core.feature.locate:  695 local maxima, 488 of qualifying mass
# mr.core.feature.batch:  Frame 169: 488 features
# mr.core.feature.locate:  708 local maxima, 485 of qualifying mass
# mr.core.feature.batch:  Frame 170: 485 features
# mr.core.feature.locate:  700 local maxima, 486 of qualifying mass
# mr.core.feature.batch:  Frame 171: 486 features
# mr.core.feature.locate:  703 local maxima, 462 of qualifying mass
# mr.core.feature.batch:  Frame 172: 462 features
# mr.core.feature.locate:  701 local maxima, 464 of qualifying mass
# mr.core.feature.batch:  Frame 173: 464 features
# mr.core.feature.locate:  695 local maxima, 456 of qualifying mass
# mr.core.feature.batch:  Frame 174: 456 features
# mr.core.feature.locate:  688 local maxima, 463 of qualifying mass
# mr.core.feature.batch:  Frame 175: 463 features
# mr.core.feature.locate:  697 local maxima, 464 of qualifying mass
# mr.core.feature.batch:  Frame 176: 464 features
# mr.core.feature.locate:  701 local maxima, 466 of qualifying mass
# mr.core.feature.batch:  Frame 177: 466 features
# mr.core.feature.locate:  700 local maxima, 456 of qualifying mass
# mr.core.feature.batch:  Frame 178: 456 features
# mr.core.feature.locate:  702 local maxima, 447 of qualifying mass
# mr.core.feature.batch:  Frame 179: 447 features
# mr.core.feature.locate:  702 local maxima, 439 of qualifying mass
# mr.core.feature.batch:  Frame 180: 439 features
# mr.core.feature.locate:  687 local maxima, 476 of qualifying mass
# mr.core.feature.batch:  Frame 181: 476 features
# mr.core.feature.locate:  701 local maxima, 449 of qualifying mass
# mr.core.feature.batch:  Frame 182: 449 features
# mr.core.feature.locate:  695 local maxima, 479 of qualifying mass
# mr.core.feature.batch:  Frame 183: 479 features
# mr.core.feature.locate:  700 local maxima, 481 of qualifying mass
# mr.core.feature.batch:  Frame 184: 481 features
# mr.core.feature.locate:  694 local maxima, 481 of qualifying mass
# mr.core.feature.batch:  Frame 185: 481 features
# mr.core.feature.locate:  696 local maxima, 462 of qualifying mass
# mr.core.feature.batch:  Frame 186: 462 features
# mr.core.feature.locate:  701 local maxima, 474 of qualifying mass
# mr.core.feature.batch:  Frame 187: 474 features
# mr.core.feature.locate:  696 local maxima, 458 of qualifying mass
# mr.core.feature.batch:  Frame 188: 458 features
# mr.core.feature.locate:  698 local maxima, 447 of qualifying mass
# mr.core.feature.batch:  Frame 189: 447 features
# mr.core.feature.locate:  691 local maxima, 467 of qualifying mass
# mr.core.feature.batch:  Frame 190: 467 features
# mr.core.feature.locate:  697 local maxima, 470 of qualifying mass
# mr.core.feature.batch:  Frame 191: 470 features
# mr.core.feature.locate:  695 local maxima, 476 of qualifying mass
# mr.core.feature.batch:  Frame 192: 476 features
# mr.core.feature.locate:  699 local maxima, 492 of qualifying mass
# mr.core.feature.batch:  Frame 193: 492 features
# mr.core.feature.locate:  686 local maxima, 451 of qualifying mass
# mr.core.feature.batch:  Frame 194: 451 features
# mr.core.feature.locate:  705 local maxima, 465 of qualifying mass
# mr.core.feature.batch:  Frame 195: 465 features
# mr.core.feature.locate:  706 local maxima, 453 of qualifying mass
# mr.core.feature.batch:  Frame 196: 453 features
# mr.core.feature.locate:  710 local maxima, 498 of qualifying mass
# mr.core.feature.batch:  Frame 197: 498 features
# mr.core.feature.locate:  709 local maxima, 504 of qualifying mass
# mr.core.feature.batch:  Frame 198: 504 features
# mr.core.feature.locate:  701 local maxima, 483 of qualifying mass
# mr.core.feature.batch:  Frame 199: 483 features
# mr.core.feature.locate:  703 local maxima, 496 of qualifying mass
# mr.core.feature.batch:  Frame 200: 496 features
# mr.core.feature.locate:  703 local maxima, 484 of qualifying mass
# mr.core.feature.batch:  Frame 201: 484 features
# mr.core.feature.locate:  717 local maxima, 496 of qualifying mass
# mr.core.feature.batch:  Frame 202: 496 features
# mr.core.feature.locate:  718 local maxima, 492 of qualifying mass
# mr.core.feature.batch:  Frame 203: 492 features
# mr.core.feature.locate:  726 local maxima, 498 of qualifying mass
# mr.core.feature.batch:  Frame 204: 498 features
# mr.core.feature.locate:  707 local maxima, 499 of qualifying mass
# mr.core.feature.batch:  Frame 205: 499 features
# mr.core.feature.locate:  707 local maxima, 502 of qualifying mass
# mr.core.feature.batch:  Frame 206: 502 features
# mr.core.feature.locate:  706 local maxima, 495 of qualifying mass
# mr.core.feature.batch:  Frame 207: 495 features
# mr.core.feature.locate:  711 local maxima, 528 of qualifying mass
# mr.core.feature.batch:  Frame 208: 528 features
# mr.core.feature.locate:  704 local maxima, 492 of qualifying mass
# mr.core.feature.batch:  Frame 209: 492 features
# mr.core.feature.locate:  703 local maxima, 505 of qualifying mass
# mr.core.feature.batch:  Frame 210: 505 features
# mr.core.feature.locate:  708 local maxima, 496 of qualifying mass
# mr.core.feature.batch:  Frame 211: 496 features
# mr.core.feature.locate:  715 local maxima, 491 of qualifying mass
# mr.core.feature.batch:  Frame 212: 491 features
# mr.core.feature.locate:  690 local maxima, 480 of qualifying mass
# mr.core.feature.batch:  Frame 213: 480 features
# mr.core.feature.locate:  689 local maxima, 510 of qualifying mass
# mr.core.feature.batch:  Frame 214: 510 features
# mr.core.feature.locate:  698 local maxima, 495 of qualifying mass
# mr.core.feature.batch:  Frame 215: 495 features
# mr.core.feature.locate:  702 local maxima, 507 of qualifying mass
# mr.core.feature.batch:  Frame 216: 507 features
# mr.core.feature.locate:  712 local maxima, 498 of qualifying mass
# mr.core.feature.batch:  Frame 217: 498 features
# mr.core.feature.locate:  702 local maxima, 518 of qualifying mass
# mr.core.feature.batch:  Frame 218: 518 features
# mr.core.feature.locate:  710 local maxima, 496 of qualifying mass
# mr.core.feature.batch:  Frame 219: 496 features
# mr.core.feature.locate:  709 local maxima, 501 of qualifying mass
# mr.core.feature.batch:  Frame 220: 501 features
# mr.core.feature.locate:  716 local maxima, 497 of qualifying mass
# mr.core.feature.batch:  Frame 221: 497 features
# mr.core.feature.locate:  706 local maxima, 499 of qualifying mass
# mr.core.feature.batch:  Frame 222: 499 features
# mr.core.feature.locate:  712 local maxima, 495 of qualifying mass
# mr.core.feature.batch:  Frame 223: 495 features
# mr.core.feature.locate:  723 local maxima, 493 of qualifying mass
# mr.core.feature.batch:  Frame 224: 493 features
# mr.core.feature.locate:  708 local maxima, 465 of qualifying mass
# mr.core.feature.batch:  Frame 225: 465 features
# mr.core.feature.locate:  710 local maxima, 467 of qualifying mass
# mr.core.feature.batch:  Frame 226: 467 features
# mr.core.feature.locate:  709 local maxima, 472 of qualifying mass
# mr.core.feature.batch:  Frame 227: 472 features
# mr.core.feature.locate:  700 local maxima, 454 of qualifying mass
# mr.core.feature.batch:  Frame 228: 454 features
# mr.core.feature.locate:  696 local maxima, 487 of qualifying mass
# mr.core.feature.batch:  Frame 229: 487 features
# mr.core.feature.locate:  700 local maxima, 494 of qualifying mass
# mr.core.feature.batch:  Frame 230: 494 features
# mr.core.feature.locate:  699 local maxima, 456 of qualifying mass
# mr.core.feature.batch:  Frame 231: 456 features
# mr.core.feature.locate:  706 local maxima, 464 of qualifying mass
# mr.core.feature.batch:  Frame 232: 464 features
# mr.core.feature.locate:  701 local maxima, 482 of qualifying mass
# mr.core.feature.batch:  Frame 233: 482 features
# mr.core.feature.locate:  706 local maxima, 489 of qualifying mass
# mr.core.feature.batch:  Frame 234: 489 features
# mr.core.feature.locate:  700 local maxima, 480 of qualifying mass
# mr.core.feature.batch:  Frame 235: 480 features
# mr.core.feature.locate:  705 local maxima, 471 of qualifying mass
# mr.core.feature.batch:  Frame 236: 471 features
# mr.core.feature.locate:  696 local maxima, 462 of qualifying mass
# mr.core.feature.batch:  Frame 237: 462 features
# mr.core.feature.locate:  702 local maxima, 458 of qualifying mass
# mr.core.feature.batch:  Frame 238: 458 features
# mr.core.feature.locate:  704 local maxima, 480 of qualifying mass
# mr.core.feature.batch:  Frame 239: 480 features
# mr.core.feature.locate:  694 local maxima, 479 of qualifying mass
# mr.core.feature.batch:  Frame 240: 479 features
# mr.core.feature.locate:  699 local maxima, 461 of qualifying mass
# mr.core.feature.batch:  Frame 241: 461 features
# mr.core.feature.locate:  706 local maxima, 471 of qualifying mass
# mr.core.feature.batch:  Frame 242: 471 features
# mr.core.feature.locate:  708 local maxima, 489 of qualifying mass
# mr.core.feature.batch:  Frame 243: 489 features
# mr.core.feature.locate:  704 local maxima, 476 of qualifying mass
# mr.core.feature.batch:  Frame 244: 476 features
# mr.core.feature.locate:  710 local maxima, 482 of qualifying mass
# mr.core.feature.batch:  Frame 245: 482 features
# mr.core.feature.locate:  725 local maxima, 491 of qualifying mass
# mr.core.feature.batch:  Frame 246: 491 features
# mr.core.feature.locate:  706 local maxima, 491 of qualifying mass
# mr.core.feature.batch:  Frame 247: 491 features
# mr.core.feature.locate:  702 local maxima, 521 of qualifying mass
# mr.core.feature.batch:  Frame 248: 521 features
# mr.core.feature.locate:  701 local maxima, 509 of qualifying mass
# mr.core.feature.batch:  Frame 249: 509 features
# mr.core.feature.locate:  710 local maxima, 517 of qualifying mass
# mr.core.feature.batch:  Frame 250: 517 features
# mr.core.feature.locate:  695 local maxima, 475 of qualifying mass
# mr.core.feature.batch:  Frame 251: 475 features
# mr.core.feature.locate:  689 local maxima, 459 of qualifying mass
# mr.core.feature.batch:  Frame 252: 459 features
# mr.core.feature.locate:  693 local maxima, 470 of qualifying mass
# mr.core.feature.batch:  Frame 253: 470 features
# mr.core.feature.locate:  697 local maxima, 475 of qualifying mass
# mr.core.feature.batch:  Frame 254: 475 features
# mr.core.feature.locate:  689 local maxima, 497 of qualifying mass
# mr.core.feature.batch:  Frame 255: 497 features
# mr.core.feature.locate:  691 local maxima, 480 of qualifying mass
# mr.core.feature.batch:  Frame 256: 480 features
# mr.core.feature.locate:  693 local maxima, 506 of qualifying mass
# mr.core.feature.batch:  Frame 257: 506 features
# mr.core.feature.locate:  707 local maxima, 483 of qualifying mass
# mr.core.feature.batch:  Frame 258: 483 features
# mr.core.feature.locate:  693 local maxima, 507 of qualifying mass
# mr.core.feature.batch:  Frame 259: 507 features
# mr.core.feature.locate:  700 local maxima, 510 of qualifying mass
# mr.core.feature.batch:  Frame 260: 510 features
# mr.core.feature.locate:  716 local maxima, 521 of qualifying mass
# mr.core.feature.batch:  Frame 261: 521 features
# mr.core.feature.locate:  713 local maxima, 492 of qualifying mass
# mr.core.feature.batch:  Frame 262: 492 features
# mr.core.feature.locate:  696 local maxima, 506 of qualifying mass
# mr.core.feature.batch:  Frame 263: 506 features
# mr.core.feature.locate:  698 local maxima, 506 of qualifying mass
# mr.core.feature.batch:  Frame 264: 506 features
# mr.core.feature.locate:  698 local maxima, 492 of qualifying mass
# mr.core.feature.batch:  Frame 265: 492 features
# mr.core.feature.locate:  706 local maxima, 481 of qualifying mass
# mr.core.feature.batch:  Frame 266: 481 features
# mr.core.feature.locate:  697 local maxima, 515 of qualifying mass
# mr.core.feature.batch:  Frame 267: 515 features
# mr.core.feature.locate:  697 local maxima, 473 of qualifying mass
# mr.core.feature.batch:  Frame 268: 473 features
# mr.core.feature.locate:  692 local maxima, 479 of qualifying mass
# mr.core.feature.batch:  Frame 269: 479 features
# mr.core.feature.locate:  709 local maxima, 461 of qualifying mass
# mr.core.feature.batch:  Frame 270: 461 features
# mr.core.feature.locate:  714 local maxima, 482 of qualifying mass
# mr.core.feature.batch:  Frame 271: 482 features
# mr.core.feature.locate:  705 local maxima, 483 of qualifying mass
# mr.core.feature.batch:  Frame 272: 483 features
# mr.core.feature.locate:  714 local maxima, 484 of qualifying mass
# mr.core.feature.batch:  Frame 273: 484 features
# mr.core.feature.locate:  718 local maxima, 466 of qualifying mass
# mr.core.feature.batch:  Frame 274: 466 features
# mr.core.feature.locate:  705 local maxima, 472 of qualifying mass
# mr.core.feature.batch:  Frame 275: 472 features
# mr.core.feature.locate:  716 local maxima, 489 of qualifying mass
# mr.core.feature.batch:  Frame 276: 489 features
# mr.core.feature.locate:  705 local maxima, 473 of qualifying mass
# mr.core.feature.batch:  Frame 277: 473 features
# mr.core.feature.locate:  710 local maxima, 461 of qualifying mass
# mr.core.feature.batch:  Frame 278: 461 features
# mr.core.feature.locate:  708 local maxima, 473 of qualifying mass
# mr.core.feature.batch:  Frame 279: 473 features
# mr.core.feature.locate:  701 local maxima, 463 of qualifying mass
# mr.core.feature.batch:  Frame 280: 463 features
# mr.core.feature.locate:  695 local maxima, 489 of qualifying mass
# mr.core.feature.batch:  Frame 281: 489 features
# mr.core.feature.locate:  691 local maxima, 485 of qualifying mass
# mr.core.feature.batch:  Frame 282: 485 features
# mr.core.feature.locate:  683 local maxima, 481 of qualifying mass
# mr.core.feature.batch:  Frame 283: 481 features
# mr.core.feature.locate:  689 local maxima, 489 of qualifying mass
# mr.core.feature.batch:  Frame 284: 489 features
# mr.core.feature.locate:  691 local maxima, 463 of qualifying mass
# mr.core.feature.batch:  Frame 285: 463 features
# mr.core.feature.locate:  693 local maxima, 460 of qualifying mass
# mr.core.feature.batch:  Frame 286: 460 features
# mr.core.feature.locate:  685 local maxima, 477 of qualifying mass
# mr.core.feature.batch:  Frame 287: 477 features
# mr.core.feature.locate:  697 local maxima, 460 of qualifying mass
# mr.core.feature.batch:  Frame 288: 460 features
# mr.core.feature.locate:  699 local maxima, 466 of qualifying mass
# mr.core.feature.batch:  Frame 289: 466 features
# mr.core.feature.locate:  693 local maxima, 469 of qualifying mass
# mr.core.feature.batch:  Frame 290: 469 features
# mr.core.feature.locate:  697 local maxima, 482 of qualifying mass
# mr.core.feature.batch:  Frame 291: 482 features
# mr.core.feature.locate:  698 local maxima, 491 of qualifying mass
# mr.core.feature.batch:  Frame 292: 491 features
# mr.core.feature.locate:  687 local maxima, 470 of qualifying mass
# mr.core.feature.batch:  Frame 293: 470 features
# mr.core.feature.locate:  708 local maxima, 444 of qualifying mass
# mr.core.feature.batch:  Frame 294: 444 features
# mr.core.feature.locate:  703 local maxima, 480 of qualifying mass
# mr.core.feature.batch:  Frame 295: 480 features
# mr.core.feature.locate:  695 local maxima, 491 of qualifying mass
# mr.core.feature.batch:  Frame 296: 491 features
# mr.core.feature.locate:  696 local maxima, 496 of qualifying mass
# mr.core.feature.batch:  Frame 297: 496 features
# mr.core.feature.locate:  700 local maxima, 489 of qualifying mass
# mr.core.feature.batch:  Frame 298: 489 features
# mr.core.feature.locate:  700 local maxima, 504 of qualifying mass
# mr.core.feature.batch:  Frame 299: 504 features
# mr.core.feature.locate:  697 local maxima, 516 of qualifying mass
# mr.core.feature.batch:  Frame 300: 516 features

# %%
mr.circle(f, frames[:300]) # spawn a window playing the video with features circled
# Out:
# Press Ctrl+C to interrupt video.

# %% [markdown]
# ## Link features into particle trajectories
# We have the locations of the particles in each frame. Next we'll associate each particle with an ID number and track it from frame to frame.
#
# First, we must must specify a maximum displacement, the farthest a particle is likely to travel between frames. We must not underestimate how far a particle might travel, but we should choose the smallest reasonable value because a large value slows computation time considerably. In this case, 5 pixels is reasonable.
#
# Second, we allow for the possibility that a particle might be missed in one frame and then seen again in the next frame. (Perhaps its "mass" slipped below our cutoff due to noise in the video.) Memory keeps track of disappeared particles and maintains their ID for up to some number of frames after their last appearance. We'll choose 3.

# %%
t = mr.track(f, 5, memory=3)
# Out:
# Organizing the output...
# Building Feature objects...
# Doing the actual work...
# Organizing the output...

# %% [markdown]
# Compare the features ``f`` to the trajectories ``t``, and observe the new column, ``probe``, which gives each unique particle an ID number.

# %%
f.head()
# Out:
#             x         y  mass      size       ecc     signal        ep  frame
# 0  294.564189  5.722973  2664  2.201300  0.160637  27.279131  0.479596      0
# 2   36.048647  8.120968  3844  2.771191  0.146392  22.279131  0.370538      0
# 3   67.232830  7.869478  3509  2.570799  0.053752  23.279131  0.412061      0
# 4  273.685474  8.457684  2375  2.832444  0.241892  12.279131  0.643538      0
# 5  430.957784  7.319437  5685  2.763565  0.288109  26.279131  0.315874      0

# %%
t.head()
# Out:
#             x         y  mass      size       ecc     signal        ep  frame  \
# 0  294.564189  5.722973  2664  2.201300  0.160637  27.279131  0.479596      0
# 1   36.048647  8.120968  3844  2.771191  0.146392  22.279131  0.370538      0
# 2   67.232830  7.869478  3509  2.570799  0.053752  23.279131  0.412061      0
# 3  273.685474  8.457684  2375  2.832444  0.241892  12.279131  0.643538      0
# 4  430.957784  7.319437  5685  2.763565  0.288109  26.279131  0.315874      0
#
#    probe
# 0     89
# 1     27
# 2    413
# 3     90
# 4     16

# %% [markdown]
# We have more filtering to do. Empheremeral trajectories, seen only for a few frames are probably not real or, if real, not useful. This  convenience function filters out trajectories of short duration - in this case, < 50 frames.

# %%
t1 = mr.bust_ghosts(t, 50)
# Compare the number of probes in the unfiltered and filtered data.
t['probe'].nunique(), t1['probe'].nunique()
# Out:
# (8122, 729)

# %% [markdown]
# Trace the trajectories.

# %%
t1 = t1.drop_duplicates(['frame', 'probe']) # work around bug in trackpy -- not always necessary
mr.plot_traj(t1)
# Out:
# mr.core.plots.plot_traj:  Using units of px, not microns

# %% [markdown]
# ### Remove overall drift
#
# Compute the overall drifting motion, which we will subtract away, adopting the reference frame of the probes' average position.

# %%
d = mr.compute_drift(t1)

# %%
1.74d.plot()

# %%
tm = mr.subtract_drift(t1, d)

# %% [markdown]
# With the overall drifting motion subtracted out, we plot the trajectories again. We observe nice random walks.

# %%
mr.plot_traj(tm)
# Out:
# mr.core.plots.plot_traj:  Using units of px, not microns

# %% [markdown]
# ## Analyze trajectories
#
# ### Mean Squared Displacement of Individal Probes

# %% [markdown]
# Compute the mean squared displacement of each particle and plot MSD vs. lag time.

# %%
im = mr.imsd(tm, 100/285., 24) # microns per pixel = 100/285., frames per second = 24

# %%
2000im.plot(style='k-', alpha=0.1, legend=False) # black lines, semitransparent, no legend
xscale('log'); yscale('log')
ylabel(r'$\langle \Delta r^2 \rangle$ [$\mu$m$^2$]')

# %% [markdown]
# Since we only analyzed 300 frames, the statistics are poor at large lag times. With more frames, we can study larger lag times.
#
# ### Ensemble Mean Squared Displacement

# %%
em = mr.emsd(tm, 100/285., 24)

# %%
em.plot(style='o')
xscale('log'); yscale('log')

# %% [markdown]
# We can easily fit this to a power law using a convenience function, ``fit_powerlaw``, that performs a linear regression in log space.

# %%
em.plot(style='ro')
xscale('log'); yscale('log')
mr.fit_powerlaw(em)
# Out:
# hi
#            n         A
# msd  1.06742  1.701949

# %% [markdown]
# In water, a viscous material, the expected power-law exponent $n = 1$. The value of $A = 4D$, where $D$ is the particles' diffusivity. $D$ is related to viscosity $\eta$, particle radius $a$, and temperature $T$ as
#
# $D = \displaystyle\frac{kT}{6\pi\eta a}$.
#
# For paritcles with a 1 $\mu\text{m}$ diameter in room-temperature water, $A \approx 1.74$.
